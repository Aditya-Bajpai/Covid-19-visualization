# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
 
df = pd.read_csv("https://api.covid19india.org/csv/latest/raw_data21.csv")
df.head()
# Out:
#    Entry_ID  State Patient Number  ... Status Change Date  Patient Number
# 0  428033.0                   NaN  ...                NaN             NaN
# 1  428034.0                   NaN  ...                NaN             NaN
# 2  428035.0                   NaN  ...                NaN             NaN
# 3  428036.0                   NaN  ...                NaN             NaN
# 4  428037.0                   NaN  ...                NaN             NaN
#
# [5 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Entry_ID                                   11472 non-null  float64
#  1   State Patient Number                       0 non-null      float64
#  2   Date Announced                             11500 non-null  object
#  3   Age Bracket                                182 non-null    float64
#  4   Gender                                     177 non-null    object
#  5   Detected City                              10 non-null     object
#  6   Detected District                          11344 non-null  object
#  7   Detected State                             11494 non-null  object
#  8   State code                                 11487 non-null  object
#  9   Num Cases                                  11494 non-null  float64
# ...

# %%
new = df['Age Bracket'].hist(bins = 20).set_xlabel("Age Bracket")

# %%
df['Gender'].value_counts().plot(kind = 'barh')

# %% [markdown]
# This is a bar plot of the number of corona virus cases according to gender.

# %%
df['Current Status'].value_counts().plot(kind = 'barh').set_xlabel("Number of cases")
# Out:
# Text(0.5, 0, 'Number of cases')

# %%
df['Current Status'].value_counts().plot(kind = 'pie' , figsize = (6,6))
